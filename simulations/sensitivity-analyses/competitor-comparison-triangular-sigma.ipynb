# %% [markdown]
# # Competitor Comparison
#
# This is a sensitivity analysis intended to assess the impact of altering hyperparameters.
# Some of the results are summarized in the paper's appendix.
# This notebook is an old version of `competitor-comparison-triangular.ipynb`.
# It is no longer fuller functional, but these results could be reproduced by modifying the hyperparameters in the current version of `competitor-comparison-triangular.ipynb`.

# %% [markdown]
# # Shared Setup

# %%
# Generic imports
import pandas as pd
import numpy as np
import scipy
import scipy.sparse
from scipy.stats import ttest_1samp
import matplotlib.pyplot as plt
import seaborn as sns
from river import linear_model
import copy
from multiprocessing import Pool, cpu_count
import pickle
import tensorflow as tf
import keras
from keras import layers, regularizers
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-61b8y3nr because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# 2024-07-31 22:30:59.654811: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Imports from this project
from models.models import OracleTS, StandardTS, ActionCenteredTS, RoME, IntelligentPooling, UserLaplacian
from models.river_wrapper import RiverBatchEstimator
from models.bagging_mod import BaggingRegressor
from models.utils import find_neighbors
from simulations.data_generator import DataGenerator

# %%
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.tab10.colors)
plt.rcParams['font.family'] = 'sans-serif'

# %%
# Simulation setup: try some different values
N_STAGES = 200
N_OBSERVATIONS = N_STAGES * (N_STAGES + 1) // 2
N = N_STAGES
T = N_STAGES
THETA = np.array([1., 0.5, -4.])
CONTEXT_DIM = 2
EXTRA_CONTEXT_DIM = 2
LINEAR_BASELINE_COEF = np.array([2., -2., 3.])
THETA_TIME_INIT = np.array([-2., -4., 6.])
P = THETA.size
n_jobs = 25
REPS = 50
N_NEIGHBORS = 5

# %%
def get_max_norm(x):
    squared_norms = (x**2).sum(axis=1)
    norms = np.sqrt(squared_norms)
    max_norm = np.max(norms)
    return max_norm

def get_max_norm_for_pairs(x, pairs):
    x_diffs = x[pairs[0]] - x[pairs[1]]
    max_norm = get_max_norm(x_diffs)
    return max_norm

# %%
homogeneous_data_generator = DataGenerator(stage_max=N_STAGES, assumptions="homogeneous", linear_baseline_coef=LINEAR_BASELINE_COEF, random_seed=1)
homogeneous_data_generator = homogeneous_data_generator.sample_theta(theta_base=THETA)

heterogeneous_data_generator = DataGenerator(stage_max=N_STAGES, assumptions="heterogeneous", linear_baseline_coef=LINEAR_BASELINE_COEF, random_seed=1)
heterogeneous_data_generator = heterogeneous_data_generator.sample_theta(theta_base=THETA)

nonlinear_data_generator = DataGenerator(stage_max=N_STAGES, assumptions="nonlinear", random_seed=3, nonlinear_scale=1.)  # Seed chosen for its interesting nonlinear relationships
nonlinear_data_generator = nonlinear_data_generator.sample_theta(theta_base=THETA, theta_time_init=THETA_TIME_INIT)

# Baseline Reward
num_vals = 101
s1_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s2_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s1_vals_repped, s2_vals_repped = np.meshgrid(s1_vals, s2_vals)
context_values = np.vstack([s1_vals_repped.flatten(), s2_vals_repped.flatten()]).T
baseline_vals = nonlinear_data_generator._nonlinear_baseline_function(context_values, scale=nonlinear_data_generator.nonlinear_scale)
heatmap_min = np.min(baseline_vals)
heatmap_max = np.max(baseline_vals)

baseline_vals_df = pd.DataFrame(
    data=baseline_vals.reshape((num_vals, num_vals)),
    index=s1_vals,
    columns=s2_vals).sort_index(ascending=False)

fig, ax = plt.subplots(figsize=(5, 3.5))
ax = sns.heatmap(baseline_vals_df, xticklabels=10, yticklabels=10, ax=ax)
plt.xlabel("$s_{1}$")
plt.ylabel("$s_{2}$")
# plt.title("Baseline Reward as a Function of State")
fig.tight_layout()
fig.savefig("figures/baseline_reward-sigma.png")
plt.show()

# %%
# Time-specifc thetas
fig, ax = plt.subplots(figsize=(5, 3.5))
for i in range(THETA.size):
    label = "$\\theta^{(idx)}_{t}$".replace("idx", str(i))
    ax.plot(nonlinear_data_generator.theta_time[:, i], alpha=1, label=label)
ax.grid(which='major', color='#DDDDDD', linewidth=0.3)
ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.3)
ax.minorticks_on()
ax.set_xlabel("t", fontsize=13)
ax.set_ylabel("$\\theta_{t}$", fontsize=13)
# plt.title("Values of $\\theta_{time}$ Plotted Over Time")
ax.legend(fontsize=12)
fig.tight_layout()
fig.savefig("figures/theta_time-sigma.png")
plt.show()

# %%
# %%time
# Neural network stuff
nn_input_dim = CONTEXT_DIM + EXTRA_CONTEXT_DIM

featurizer_nn_models = []
for i, data_generator in enumerate([homogeneous_data_generator, heterogeneous_data_generator, nonlinear_data_generator]):
    # Create data
    data_generator = data_generator.generate_all_contexts(context_dim=CONTEXT_DIM, extra_context_dim=EXTRA_CONTEXT_DIM)
    X_train, y_train = data_generator.generate_baselines_for_nn()
    
    data_generator = data_generator.reset()
    data_generator = data_generator.generate_all_contexts(context_dim=CONTEXT_DIM, extra_context_dim=EXTRA_CONTEXT_DIM)
    X_validation, y_validation = data_generator.generate_baselines_for_nn()
    
    # Train model
    penalty = 0.001
    nn_output_dim = 10
    model = keras.Sequential(
        [
            keras.Input(shape=(nn_input_dim,), name="input"),
            layers.Dense(10, activation="relu", name="layer1", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(20, activation="relu", name="layer2", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(20, activation="tanh", name="layer3", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(nn_output_dim, activation="tanh", name="layer4", kernel_regularizer=regularizers.l2(penalty)),
            layers.Dense(1, name="output", kernel_regularizer=regularizers.l2(penalty)),
        ]
    )
    opt = keras.optimizers.Adam(learning_rate=0.01)
    model.compile(loss="mse", optimizer=opt)
    history = model.fit(
        X_train,
        y_train,
        batch_size=200,
        validation_data=(X_validation, y_validation),
        epochs=50 if i == 2 else 20,
        verbose=1
    )
    
    plt.plot(history.history['loss'], label="Train")
    plt.plot(history.history['val_loss'], label="Validation")
    plt.legend()
    plt.show()

    preds_validation = model(X_validation)
    plt.scatter(preds_validation, y_validation)
    plt.show()
    
    # Featurizer model
    featurizer_nn_model = keras.Model(
        inputs=model.input,
        outputs=model.get_layer("layer4").output)
    
    featurizer_nn_models.append(copy.deepcopy(featurizer_nn_model))

homogeneous_featurizer_nn_model = featurizer_nn_models[0]
heterogeneous_featurizer_nn_model = featurizer_nn_models[1]
nonlinear_featurizer_nn_model = featurizer_nn_models[2]
# Out:
# 2024-07-31 22:31:06.543221: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/20
# 200/200 [==============================] - 1s 2ms/step - loss: 1.5395 - val_loss: 1.1249
# Epoch 2/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0611 - val_loss: 1.1227
# Epoch 3/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0569 - val_loss: 1.0513
# Epoch 4/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0412 - val_loss: 1.0492
# Epoch 5/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0345 - val_loss: 1.0665
# Epoch 6/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0306 - val_loss: 1.0350
# Epoch 7/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0319 - val_loss: 1.0453
# Epoch 8/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0327 - val_loss: 1.0391
# Epoch 9/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0296 - val_loss: 1.0352
# Epoch 10/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0280 - val_loss: 1.0412
# Epoch 11/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0258 - val_loss: 1.0492
# Epoch 12/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0284 - val_loss: 1.0317
# Epoch 13/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0296 - val_loss: 1.0757
# Epoch 14/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0214 - val_loss: 1.0525
# Epoch 15/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0253 - val_loss: 1.0550
# Epoch 16/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0305 - val_loss: 1.0396
# Epoch 17/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0255 - val_loss: 1.0435
# Epoch 18/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0230 - val_loss: 1.0667
# Epoch 19/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0309 - val_loss: 1.0785
# Epoch 20/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0279 - val_loss: 1.0484
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:13           64
# config.json                                    2024-07-31 22:31:13         2589
# variables.h5                                   2024-07-31 22:31:13        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:12           64
# config.json                                    2024-07-31 22:31:12         2589
# variables.h5                                   2024-07-31 22:31:12        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Epoch 1/20
# 200/200 [==============================] - 1s 2ms/step - loss: 1.4990 - val_loss: 1.1057
# Epoch 2/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0780 - val_loss: 1.0727
# Epoch 3/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0627 - val_loss: 1.0951
# Epoch 4/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0561 - val_loss: 1.0603
# Epoch 5/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0541 - val_loss: 1.0697
# Epoch 6/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0462 - val_loss: 1.0430
# Epoch 7/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0407 - val_loss: 1.0618
# Epoch 8/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0386 - val_loss: 1.0451
# Epoch 9/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0400 - val_loss: 1.0521
# Epoch 10/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0392 - val_loss: 1.0398
# Epoch 11/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0379 - val_loss: 1.0592
# Epoch 12/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0397 - val_loss: 1.0645
# Epoch 13/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0442 - val_loss: 1.0381
# Epoch 14/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0379 - val_loss: 1.0348
# Epoch 15/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0409 - val_loss: 1.0480
# Epoch 16/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0350 - val_loss: 1.0468
# Epoch 17/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0359 - val_loss: 1.0420
# Epoch 18/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0334 - val_loss: 1.0468
# Epoch 19/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0394 - val_loss: 1.0535
# Epoch 20/20
# 200/200 [==============================] - 0s 1ms/step - loss: 1.0426 - val_loss: 1.0509
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:19           64
# config.json                                    2024-07-31 22:31:19         2591
# variables.h5                                   2024-07-31 22:31:19        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:18           64
# config.json                                    2024-07-31 22:31:18         2591
# variables.h5                                   2024-07-31 22:31:18        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Epoch 1/50
# 200/200 [==============================] - 1s 2ms/step - loss: 4.6399 - val_loss: 3.2111
# Epoch 2/50
# 200/200 [==============================] - 0s 1ms/step - loss: 2.9501 - val_loss: 2.7703
# Epoch 3/50
# 200/200 [==============================] - 0s 1ms/step - loss: 2.7247 - val_loss: 2.4976
# Epoch 4/50
# 200/200 [==============================] - 0s 1ms/step - loss: 2.2817 - val_loss: 1.9759
# Epoch 5/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.7117 - val_loss: 1.6152
# Epoch 6/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.5356 - val_loss: 1.4741
# Epoch 7/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.4681 - val_loss: 1.4201
# Epoch 8/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.4416 - val_loss: 1.4480
# Epoch 9/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.4549 - val_loss: 1.4332
# Epoch 10/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3908 - val_loss: 1.4295
# Epoch 11/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3885 - val_loss: 1.3253
# Epoch 12/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3816 - val_loss: 1.3996
# Epoch 13/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3982 - val_loss: 1.3147
# Epoch 14/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3842 - val_loss: 1.5091
# Epoch 15/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3670 - val_loss: 1.3435
# Epoch 16/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3508 - val_loss: 1.3496
# Epoch 17/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3672 - val_loss: 1.4445
# Epoch 18/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3371 - val_loss: 1.3567
# Epoch 19/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3716 - val_loss: 1.3224
# Epoch 20/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3703 - val_loss: 1.3619
# Epoch 21/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3651 - val_loss: 1.3323
# Epoch 22/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3521 - val_loss: 1.3275
# Epoch 23/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3503 - val_loss: 1.3786
# Epoch 24/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3357 - val_loss: 1.3607
# Epoch 25/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3439 - val_loss: 1.4059
# Epoch 26/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3517 - val_loss: 1.4417
# Epoch 27/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3405 - val_loss: 1.2896
# Epoch 28/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3358 - val_loss: 1.3871
# Epoch 29/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3474 - val_loss: 1.3170
# Epoch 30/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3675 - val_loss: 1.3200
# Epoch 31/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3383 - val_loss: 1.4392
# Epoch 32/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3444 - val_loss: 1.3597
# Epoch 33/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3277 - val_loss: 1.3891
# Epoch 34/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3412 - val_loss: 1.3529
# Epoch 35/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3469 - val_loss: 1.3551
# Epoch 36/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3225 - val_loss: 1.3216
# Epoch 37/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3192 - val_loss: 1.4480
# Epoch 38/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3399 - val_loss: 1.3547
# Epoch 39/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3301 - val_loss: 1.3623
# Epoch 40/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3401 - val_loss: 1.3236
# Epoch 41/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3188 - val_loss: 1.3746
# Epoch 42/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3130 - val_loss: 1.2999
# Epoch 43/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3179 - val_loss: 1.3549
# Epoch 44/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.2972 - val_loss: 1.3030
# Epoch 45/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3596 - val_loss: 1.3337
# Epoch 46/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3293 - val_loss: 1.2765
# Epoch 47/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3303 - val_loss: 1.3306
# Epoch 48/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3163 - val_loss: 1.3407
# Epoch 49/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3308 - val_loss: 1.2929
# Epoch 50/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.3029 - val_loss: 1.2843
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:34           64
# config.json                                    2024-07-31 22:31:34         2591
# variables.h5                                   2024-07-31 22:31:34        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:34           64
# config.json                                    2024-07-31 22:31:34         2591
# variables.h5                                   2024-07-31 22:31:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 39 s, sys: 7.6 s, total: 46.6 s
# Wall time: 28.2 s

# %%
# # Baseline Reward
num_vals = 101
s1_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s2_vals = np.round(np.linspace(-1., 1., num=num_vals), 2)
s1_vals_repped, s2_vals_repped = np.meshgrid(s1_vals, s2_vals)
context_values = np.vstack([s1_vals_repped.flatten(), s2_vals_repped.flatten()]).T
baseline_vals = nonlinear_data_generator._nonlinear_baseline_function(context_values, scale=nonlinear_data_generator.nonlinear_scale)

baseline_vals_df = pd.DataFrame(
    data=baseline_vals.reshape((num_vals, num_vals)),
    index=s1_vals,
    columns=s2_vals).sort_index(ascending=False)

fig, ax = plt.subplots(1, 2, figsize=(10, 3.5))
sns.heatmap(baseline_vals_df, vmin=heatmap_min, vmax=heatmap_max, xticklabels=10, yticklabels=10, ax=ax[0])
ax[0].set_xlabel("$s_{1}$")
ax[0].set_ylabel("$s_{2}$")

nn_context_values = np.hstack([context_values, np.zeros_like(context_values)])
nn_baseline_vals = model(nn_context_values).numpy()
nn_baseline_vals_df = pd.DataFrame(
    data=nn_baseline_vals.reshape((num_vals, num_vals)),
    index=s1_vals,
    columns=s2_vals).sort_index(ascending=False)

sns.heatmap(nn_baseline_vals_df, vmin=heatmap_min, vmax=heatmap_max, xticklabels=10, yticklabels=10, ax=ax[1])
ax[1].set_xlabel("$s_{1}$")
ax[1].set_ylabel("$s_{2}$")

fig.tight_layout()
fig.savefig("figures/nn_baseline_reward_comparison-sigma.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3.5))
ax = sns.heatmap(nn_baseline_vals_df, vmin=heatmap_min, vmax=heatmap_max, xticklabels=10, yticklabels=10, ax=ax)
plt.xlabel("$s_{1}$")
plt.ylabel("$s_{2}$")
# plt.title("Baseline Reward as a Function of State")
fig.tight_layout()
fig.savefig("figures/nn_baseline_reward-sigma.png")
plt.show()

# %%
# This determines the plotting order
non_oracle_method_names = [
    "IntelPooling",
    "RoME-BLM",
    "RoME",
    "RoME-SU",
    "AC",
    "Standard",
    "Neural-Linear",
    "NNR-Linear"
]

def create_reward_dict(data_generator, nn, seed):
    np.random.seed(seed)
    user_pairs, L_user = find_neighbors(data_generator.theta_user, N_NEIGHBORS)
    time_pairs, L_time = find_neighbors(data_generator.theta_time, N_NEIGHBORS)
    
    # Doubling these values to make them more reasonable
    d_user = get_max_norm(data_generator.theta_user) * 2
    d_time = get_max_norm(data_generator.theta_time) * 2
    b_user = get_max_norm_for_pairs(data_generator.theta_user, user_pairs) * 2
    b_time = get_max_norm_for_pairs(data_generator.theta_time, time_pairs) * 2
    bagged_lm = RiverBatchEstimator(
        BaggingRegressor(
            linear_model.LinearRegression(l2=1e-8, intercept_lr=0.1),
            n_models=10,
            subsample=0.8
        )
    )

    # Set covariances
    cov_epsilon = 1e-18
    user_cov = np.cov(data_generator.theta_user.T)
    if user_cov.sum() < cov_epsilon:
        user_cov += cov_epsilon * np.eye(user_cov.shape[0])
    time_cov = np.cov(data_generator.theta_time.T)
    if time_cov.sum() < cov_epsilon:
        time_cov += cov_epsilon * np.eye(time_cov.shape[0])

    nn_numpy = lambda x: nn(x).numpy()
    non_oracle_methods_dict = {
        "IntelPooling": IntelligentPooling(N, T, P, DataGenerator._featurize, user_cov=user_cov, time_cov=time_cov),
        "RoME": RoME(N, T, P, DataGenerator._featurize, L_user, L_time, user_cov=user_cov, time_cov=time_cov, b_user=b_user, b_time=b_time, d_user=d_user, d_time=d_time, n_neighbors=N_NEIGHBORS, sigma=10.),
        "RoME-BLM": RoME(N, T, P, DataGenerator._featurize, L_user, L_time, user_cov=user_cov, time_cov=time_cov, b_user=b_user, b_time=b_time, d_user=d_user, d_time=d_time, ml_interactions=True, ml_model=bagged_lm, n_neighbors=N_NEIGHBORS, sigma=10.),
        "RoME-SU": RoME(1, T, P, DataGenerator._featurize, L_user, L_time, user_cov=user_cov, time_cov=time_cov, b_user=b_user, b_time=b_time, d_user=d_user, d_time=d_time, n_neighbors=N_NEIGHBORS, pool_users=False, sigma=10.),
        "AC": ActionCenteredTS(N, T, P, DataGenerator._featurize),
        "Standard": StandardTS(N, T, P, DataGenerator._featurize),
        "Neural-Linear": StandardTS(N, T, P, DataGenerator._featurize, nn=nn_numpy, nn_dim=nn_output_dim),
        "NNR-Linear": UserLaplacian(N, T, P, DataGenerator._featurize, L_user, user_cov=user_cov),
    }
    methods_dict = copy.copy(non_oracle_methods_dict)
    methods_dict["Oracle"] = OracleTS(N, T, THETA, data_generator.theta_user, data_generator.theta_time, DataGenerator._featurize)
    
    # Dictionary for storing rewards
    rewards_dict = {k:np.zeros((N, T)) for k in methods_dict}

    # Generate context vectors that we'll use for all models
    data_generator = data_generator.generate_all_contexts(context_dim=CONTEXT_DIM, extra_context_dim=EXTRA_CONTEXT_DIM)

    # Iterate through methods
    for method_name, method in methods_dict.items():
        rewards = []
        data_generator = data_generator.reset()
        method.reset()

        while not data_generator.finished:
            # Randomly samples action from current policy
            context, context_extra, user_idx, time_idx = data_generator.get_current_context()
            action = method.sample_action(context, user_idx, time_idx)

            # Plays action and returns reward
            reward = data_generator.play_action(action)
            rewards_dict[method_name][user_idx, time_idx] = reward

            # Update method inferences
            method.update(context, context_extra, user_idx, time_idx, action, reward)
                
    return rewards_dict

# %%
def run_simulation(data_generator, nn, REPS=REPS, n_jobs=cpu_count()):    
    # Perform whole simulation REPS times
    with Pool(min(REPS, n_jobs)) as p:
        rewards_list_of_dicts = p.starmap(create_reward_dict, zip([data_generator]*REPS, [nn]*REPS, range(REPS)))
        
    rewards_dict = {}
    method_names = list(rewards_list_of_dicts[0].keys())
    non_oracle_method_names = list(set(method_names) - set(["Oracle"]))
    for method_name in method_names:
        rewards_dict[method_name] = np.asarray([
            rewards_list_of_dicts[i][method_name]
            for i in range(REPS)])
                
    return rewards_dict

# %%
def get_avg_stage_reward(a):
    means = [a[:, ::-1].diagonal(i, axis1=1, axis2=2).mean(axis=1) for i in range(-a.shape[1]+1,a.shape[2])]
    return np.asarray(means)[:a.shape[1]]


def plot_rewards_dict(rewards_dict, assumptions):
    fig, ax = plt.subplots(1, 2, figsize=(8, 4))
    ax0 = ax[0]
    ax1 = ax[1]
    
    # Method names
    # non_oracle_method_names = set(rewards_dict.keys()) - {"Oracle",}
    # non_oracle_method_names = sorted(list(non_oracle_method_names))

    # Calculate incremental regret
    oracle_incremental_regret = get_avg_stage_reward(rewards_dict["Oracle"])
    incremental_regret_dict = {
        method_name: (oracle_incremental_regret - get_avg_stage_reward(rewards_dict[method_name])).mean(axis=1)  # Mean over reps
        for method_name in non_oracle_method_names}

    # Calculate cumulative regret
    cumulative_regret_dict = {method_name: np.cumsum(incremental_regret_dict[method_name]) for method_name in non_oracle_method_names}

    # Plot incremental regret
    for method_name in non_oracle_method_names:
        ax0.plot(incremental_regret_dict[method_name], label=method_name, )
    ax0.set_title("(a) Incremental Regret Over Time", pad=10)
    ax0.set_ylabel("Incremental Regret")
    ax0.set_xlabel("Stage")
    ax0.legend()

    # Plot cumulative regret
    for method_name in non_oracle_method_names:
        ax1.plot(cumulative_regret_dict[method_name], label=method_name)
    ax1.set_title("(b) Cumulative Regret Over Time", pad=10)
    ax1.set_ylabel("Cumulative Regret")
    ax1.set_xlabel("Stage")
    plt.legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    fig.savefig(f"figures/{assumptions}-regret-sigma.png")
    fig.suptitle(f"Regret for {assumptions.capitalize()} Data-Generating Process")
    plt.show()

# %% [markdown]
# # Simulation 1: Homogeneous Users, Linear Baseline, No Time Effects

# %%
# %%time
homogeneous_rewards_dict = run_simulation(homogeneous_data_generator, homogeneous_featurizer_nn_model, n_jobs=n_jobs)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ...layers......denseKeras model archive loading:
#
# .........vars
# ............0
# ............1
# File Name                                             Modified             Size
# ......dense_1metadata.json                                  2024-07-31 22:31:36           64
#
# config.json                                    2024-07-31 22:31:36         2589
# .........varsvariables.h5                                   2024-07-31 22:31:36        19128
#
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ......dense_3...layers
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......dense
# File Name                                             Modified             Size
#
# ............0.........varsmetadata.json                                  2024-07-31 22:31:36           64
#
#
# config.json                                    2024-07-31 22:31:36         2589
# ............1variables.h5                                   2024-07-31 22:31:36        19128
# ............0
#
# ......input_layer............1
#
# .........vars
# ......dense_1...vars
#
# .........vars
# ............0
# ............1
# ......dense_2Keras model archive loading:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-07-31 22:31:36           64
# .........varsconfig.json                                    2024-07-31 22:31:36         2589
#
# variables.h5                                   2024-07-31 22:31:36        19128
# ............0
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ......dense_3...layers
#
# .........vars
# ......dense
# ............0
# .........vars
# ............1............0
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......input_layer
# File Name                                             Modified             Size
# ............1.........varsmetadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
#
#
# variables.h5                                   2024-07-31 22:31:36        19128
# ...vars......dense_1
#
# .........vars
# ............0
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# metadata.json                                  2024-07-31 22:31:36           64
# ...layersconfig.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# ............1
#
# ......dense_2
# ......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# .........vars.........vars
# ............0Keras model archive loading:
#
# File Name                                             Modified             Size
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
#
# ............1
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras model archive loading:
# ............1
# File Name                                             Modified             Size
#
# ......dense_1......dense_3metadata.json                                  2024-07-31 22:31:36           64
# ...layers
# config.json                                    2024-07-31 22:31:36         2589
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# ......densevariables.h5                                   2024-07-31 22:31:36        19128
#
# .........vars
# ............0
#
#
# ............1variables.h5                                   2024-07-31 22:31:36        19128
# ...layers.........vars
#
#
# ......dense_1......dense............0
#
# ............0
# .........vars.........varsKeras model archive loading:
#
#
# ............1............0
# ............1
# File Name                                             Modified             Size
#
# metadata.json                                  2024-07-31 22:31:36           64
# ............1......dense_2......input_layer
#
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
#
# .........vars
# ......dense_2Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
#
# ............0.........varsFile Name                                             Modified             Size
# ............0metadata.json                                  2024-07-31 22:31:36           64
#
# .........vars
#
# ...varsconfig.json                                    2024-07-31 22:31:36         2589
#
# ............1
# variables.h5                                   2024-07-31 22:31:36        19128
# ............0
# ............1
#
# ......dense_1............1
# ......dense_3
#
# .........vars......dense_3.........vars
#
#
# ............0.........vars............0Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
#
#
# ............0File Name                                             Modified             Size
# ............1
# ............1
#
# metadata.json                                  2024-07-31 22:31:36           64
# ............1......dense_2......input_layer
#
# config.json                                    2024-07-31 22:31:36         2589
# .........vars
# .........vars............0variables.h5                                   2024-07-31 22:31:36        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...vars
#
# ............1...layers
#
# ......dense_3......dense
#
# .........vars
# .........vars
# ............0
#
# ......input_layer............0
# ............1
#
# .........vars
# ............1......input_layer...vars
#
#
# .........vars......dense_1
# Keras model archive loading:
#
# ...vars.........vars
#
# File Name                                             Modified             Size
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# metadata.json                                  2024-07-31 22:31:36           64
# Keras model archive loading:
#
# File Name                                             Modified             Size
# ............1metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# config.json                                    2024-07-31 22:31:36         2589
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:variables.h5                                   2024-07-31 22:31:36        19128
# ......dense_2Keras model archive loading:
#
# variables.h5                                   2024-07-31 22:31:36        19128
# File Name                                             Modified             Size
# .........varsmetadata.json                                  2024-07-31 22:31:36           64
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-07-31 22:31:36         2589
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# variables.h5                                   2024-07-31 22:31:36        19128
#
# ...layers
# Keras model archive loading:
# File Name                                             Modified             Size
# ...layers
#
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# ......dense
# .........varsvariables.h5                                   2024-07-31 22:31:36        19128
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ............0
#
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense............0
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras model archive loading:
#
#
# ......dense_3
# ...layers
#
# ............0.........vars
#
# ............1
# ......dense......input_layer
#
#
# .........vars.........vars.........vars
#
# ......dense_1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# .........vars...varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# ...layersFile Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
#
# config.json                                    2024-07-31 22:31:36         2589
# ............0variables.h5                                   2024-07-31 22:31:36        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......dense............0Keras model archive loading:
#
# .........vars
# ...layers
# ......dense............0
#
#
# .........vars
# File Name                                             Modified             Size
# ............1
# ............1............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# metadata.json                                  2024-07-31 22:31:36           64
# ............0
#
#
#
#
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
#
# ......dense_1............0
# ...layers......dense_1.........vars............1
# ......dense_1
#
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ............0
# .........vars............0File Name                                             Modified             Size
#
# ............1metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
#
#
# ............1......dense_2
# ............1
#
# ............0
# .........vars............1
# ............0
# Keras model archive loading:
# ............1
# File Name                                             Modified             Size
#
# ......dense
# ......dense_2......dense_1
# .........vars
#
# ............0
# ......dense_2.........vars............1
# ............0
#
# ......dense_2.........vars............1
#
#
# ......dense_1......dense_3
#
# .........vars
# ............0
# ............0......dense_3.........varsmetadata.json                                  2024-07-31 22:31:36           64
#
#
# config.json                                    2024-07-31 22:31:36         2589
# ............0
#
#
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
#
# .........vars...layers......dense_2
# .........vars............1
# .........vars
# ............0......input_layer
#
#
#
# ............1............0
#
# ......input_layer
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# variables.h5                                   2024-07-31 22:31:36        19128
# ......input_layer......dense
#
# .........vars.........vars......dense
# .........vars
# ............1............0
#
#
# ............1...vars.........vars
#
#
# ...vars......dense_2
#
# Keras model archive loading:
#
# .........vars
# ............1File Name                                             Modified             Size
#
# metadata.json                                  2024-07-31 22:31:36           64
# ......dense_3............0
# .........vars
# ............0
#
# ............1............0
# config.json                                    2024-07-31 22:31:36         2589
#
#
# ......dense_3............1
#
# ......dense_3.........varsvariables.h5                                   2024-07-31 22:31:36        19128
#
# ......dense_3
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
#
# ............0...layers
# ............1............1
#
# ......input_layer
# .........vars
#
# ............0
# ............0............1
# .........vars
#
# ............0.........vars............1
# ............0
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ............1File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
#
# variables.h5                                   2024-07-31 22:31:36        19128
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense_1......input_layer
#
#
#
# ...vars.........vars...layers............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras model archive loading:
#
# .........vars......dense
# File Name                                             Modified             Size
#
# ...vars
#
# ...vars
# .........vars
#
#
# ......dense...layersmetadata.json                                  2024-07-31 22:31:36           64
#
# config.json                                    2024-07-31 22:31:36         2589
# ............0......dense_1variables.h5                                   2024-07-31 22:31:36        19128
#
#
# ............0............1.........vars
#
#
# ......dense_2.........vars
# ......input_layer
#
# ............0............1
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............0
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# ............1
#
# ......dense_1
# .........vars
# ...vars
#
# ............1Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# .........vars
# ............0......dense_1............0
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
#
# .........vars
# ............1............1
#
#
#
# ......dense_2......dense_2
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# ............0variables.h5                                   2024-07-31 22:31:36        19128
# .........vars
# ............1
# ......dense_2
# Keras model archive loading:
# .........vars
# ......dense_3Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# File Name                                             Modified             Size
#
# .........vars.........vars
# metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
#
# variables.h5                                   2024-07-31 22:31:36        19128
#
# ............0metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# ............0............0............0
#
#
# ............1
# ......dense_3
# .........vars
# ............0
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
#
# Keras model archive loading:
# ............1File Name                                             Modified             Size
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:37           64
#
# config.json                                    2024-07-31 22:31:37         2589
# metadata.json                                  2024-07-31 22:31:36           64
# variables.h5                                   2024-07-31 22:31:37        19128
# ...layers......input_layer
# ............1config.json                                    2024-07-31 22:31:36         2589
# .........vars
#
# ...vars
# ......input_layervariables.h5                                   2024-07-31 22:31:36        19128
#
#
#
# .........vars
#
# ............1......dense
#
# ......dense_3.........vars
# Keras model archive loading:
# ...vars
# .........varsFile Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# ......dense_3config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-07-31 22:31:37           64
# config.json                                    2024-07-31 22:31:37         2589
# variables.h5                                   2024-07-31 22:31:37        19128
# .........vars
#
# Keras model archive loading:
# File Name                                             Modified             Size
# ............0............0metadata.json                                  2024-07-31 22:31:36           64
# config.json                                    2024-07-31 22:31:36         2589
#
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:37           64
# config.json                                    2024-07-31 22:31:37         2589
# ............1variables.h5                                   2024-07-31 22:31:37        19128
#
# ............0............1...layers
# ......dense
# ...layers
#
# .........vars
# ............0
# ............1
#
#
# Keras model archive loading:
#
# ......dense_1......input_layerFile Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ......dense............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:37           64
# ............1config.json                                    2024-07-31 22:31:37         2589
#
#
# variables.h5                                   2024-07-31 22:31:37        19128
# .........vars
# ............0
#
# .........vars............1
# ......input_layer
# ......dense_1
#
#
# metadata.json                                  2024-07-31 22:31:36           64
# Keras model archive loading:
# .........vars......dense_1.........vars
# .........vars............0............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
#
# ...layers............1
# ......dense_2
# .........vars
# ............0.........vars...layers
#
#
#
#
# config.json                                    2024-07-31 22:31:36         2589
# ............1File Name                                             Modified             Size
#
# ......densemetadata.json                                  2024-07-31 22:31:36           64
# variables.h5                                   2024-07-31 22:31:36        19128
#
#
# ............0......dense...vars
# config.json                                    2024-07-31 22:31:36         2589
# .........vars............1
# variables.h5                                   2024-07-31 22:31:36        19128
#
# ............0......dense_2......dense_3
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ............1
# ............0
# ...layers
# ......dense_1............1
# ......dense
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# .........vars
#
# .........varsFile Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:37           64
# config.json                                    2024-07-31 22:31:37         2589
# variables.h5                                   2024-07-31 22:31:37        19128
#
# .........vars......dense_2
#
# ............0
# ............0
# ............1
# ............0
#
# .........vars............1............0
#
# ............1............1
# ............1
#
# ......dense_1
# ............0......dense_3......input_layerKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......dense_1
#
#
# ............1
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......dense_3...layers
#
# .........vars.........vars.........vars
# ............0
# .........vars......dense............1
#
#
# .........vars......dense_2...vars.........vars......input_layer
#
#
#
# .........vars.........vars
#
# ............0...vars
#
#
# ............1
# ............0...layers
#
# ............0......dense
#
#
# .........vars......dense_3
#
# ............0.........vars
#
# ............0............1
# ............1
#
# ............0......input_layer
# .........vars
# ......dense_1
# .........vars............1
#
#
# ...vars
# ............0
#
# ............1............1
# ......dense_1
#
#
# ............0............1
# ......input_layer......dense_2
#
#
# ............1.........vars
# ......dense_2
# .........vars.........vars......dense_2
#
#
# .........vars............0............0
#
# ............0
#
# ............1
# ............1
# .........vars
# ...vars
# ............1......dense_2
# ............0
#
# ......dense_3............1
#
# ......dense_3
#
# .........vars.........vars.........vars
# ......dense_3
# .........vars
# ............0
#
#
# ............0
# ............0............1
# ......dense_3
# ............1.........vars
#
# ............0............1
# ......input_layer
#
# .........vars
# ...vars
# ......input_layer
# ............0............1
#
#
# .........vars............1......input_layer
#
#
# ...vars.........vars......input_layer
#
# ...vars
# .........vars
#
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-07-31 22:31:36           64
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:33:48           64
# config.json                                    2024-08-01 00:33:48         2589
# variables.h5                                   2024-08-01 00:33:48        19128
# config.json                                    2024-07-31 22:31:36         2589
# variables.h5                                   2024-07-31 22:31:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:35:46           64
# config.json                                    2024-08-01 00:35:46         2589
# variables.h5                                   2024-08-01 00:35:46        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:33:48           64
# config.json                                    2024-08-01 00:33:48         2589
# variables.h5                                   2024-08-01 00:33:48        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:04           64
# config.json                                    2024-08-01 00:36:04         2589
# variables.h5                                   2024-08-01 00:36:04        19128
# metadata.json                                  2024-08-01 00:35:46           64
# config.json                                    2024-08-01 00:35:46         2589
# variables.h5                                   2024-08-01 00:35:46        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:11           64
# config.json                                    2024-08-01 00:36:11         2589
# variables.h5                                   2024-08-01 00:36:11        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:04           64
# config.json                                    2024-08-01 00:36:04         2589
# variables.h5                                   2024-08-01 00:36:04        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:15           64
# config.json                                    2024-08-01 00:36:15         2589
# variables.h5                                   2024-08-01 00:36:15        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:10           64
# config.json                                    2024-08-01 00:36:10         2589
# variables.h5                                   2024-08-01 00:36:10        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# Keras model archive loading:
# File Name                                             Modified             Size
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:16           64
# config.json                                    2024-08-01 00:36:16         2589
# variables.h5                                   2024-08-01 00:36:16        19128
# metadata.json                                  2024-08-01 00:36:14           64
# config.json                                    2024-08-01 00:36:14         2589
#
# ......dense_2
# variables.h5                                   2024-08-01 00:36:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:16           64
# config.json                                    2024-08-01 00:36:16         2589
# variables.h5                                   2024-08-01 00:36:16        19128
# .........varsKeras model archive loading:
#
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# File Name                                             Modified             Size
# ............1metadata.json                                  2024-08-01 00:36:16           64
# config.json                                    2024-08-01 00:36:16         2589
#
# ......input_layervariables.h5                                   2024-08-01 00:36:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ...layers
# .........vars......dense
#
# ...vars
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............0
# ...layers............1
#
# ......dense_1......dense
#
# .........vars.........vars
#
# ............0............0
# ............1
#
# ......dense_2............1
#
# ......dense_1.........vars
#
# ............0.........vars
#
# ............1............0
# ......dense_3
# ............1
#
# ......dense_2
# .........vars.........vars
#
# ............0............0
# ............1
# ............1
# ......dense_3
#
# ......input_layer
# .........vars.........vars
#
# ............0
# ...vars............1
#
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:29           64
# config.json                                    2024-08-01 00:36:29         2589
# variables.h5                                   2024-08-01 00:36:29        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:16           64
# config.json                                    2024-08-01 00:36:16         2589
# variables.h5                                   2024-08-01 00:36:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:31           64
# config.json                                    2024-08-01 00:36:31         2589
# variables.h5                                   2024-08-01 00:36:31        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:28           64
# config.json                                    2024-08-01 00:36:28         2589
# variables.h5                                   2024-08-01 00:36:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:34           64
# ...
#
# ............1............0
#
# ............1
# ......input_layer......input_layer
#
# .........vars
# .........vars...vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:38           64
# config.json                                    2024-08-01 00:36:38         2589
# variables.h5                                   2024-08-01 00:36:38        19128
# Keras model archive loading:
# ...varsFile Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:36           64
#
# config.json                                    2024-08-01 00:36:36         2589
# variables.h5                                   2024-08-01 00:36:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# metadata.json                                  2024-08-01 00:36:38           64
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:40           64
# config.json                                    2024-08-01 00:36:40         2589
# variables.h5                                   2024-08-01 00:36:40        19128
# config.json                                    2024-08-01 00:36:38         2589
# variables.h5                                   2024-08-01 00:36:38        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:41           64
# config.json                                    2024-08-01 00:36:41         2589
# variables.h5                                   2024-08-01 00:36:41        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:40           64
# config.json                                    2024-08-01 00:36:40         2589
# variables.h5                                   2024-08-01 00:36:40        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:42           64
# config.json                                    2024-08-01 00:36:42         2589
# variables.h5                                   2024-08-01 00:36:42        19128
#
# File Name                                             Modified             Size
# ............0metadata.json                                  2024-08-01 00:36:40           64
# config.json                                    2024-08-01 00:36:40         2589
# variables.h5                                   2024-08-01 00:36:40        19128
#
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......input_layer...layers
#
# .........vars......dense
# .........vars
# ............0
# ...vars
# ............1
#
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:43           64
# config.json                                    2024-08-01 00:36:43         2589
# variables.h5                                   2024-08-01 00:36:43        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:42           64
# config.json                                    2024-08-01 00:36:42         2589
# variables.h5                                   2024-08-01 00:36:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:38:27           64
# config.json                                    2024-08-01 00:38:27         2589
# variables.h5                                   2024-08-01 00:38:27        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:36:42           64
# config.json                                    2024-08-01 00:36:42         2589
# variables.h5                                   2024-08-01 00:36:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:41:17           64
# config.json                                    2024-08-01 00:41:17         2589
# variables.h5                                   2024-08-01 00:41:17        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:38:26           64
# config.json                                    2024-08-01 00:38:26         2589
# variables.h5                                   2024-08-01 00:38:26        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:43:30           64
# config.json                                    2024-08-01 00:43:30         2589
# variables.h5                                   2024-08-01 00:43:30        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:41:16           64
# config.json                                    2024-08-01 00:41:16         2589
# variables.h5                                   2024-08-01 00:41:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:45:24           64
# config.json                                    2024-08-01 00:45:24         2589
# variables.h5                                   2024-08-01 00:45:24        19128
# metadata.json                                  2024-08-01 00:43:30           64
# config.json                                    2024-08-01 00:43:30         2589
# variables.h5                                   2024-08-01 00:43:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:45:24           64
# config.json                                    2024-08-01 00:45:24         2589
# variables.h5                                   2024-08-01 00:45:24        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:45:51           64
# config.json                                    2024-08-01 00:45:51         2589
# variables.h5                                   2024-08-01 00:45:51        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:45:50           64
# config.json                                    2024-08-01 00:45:50         2589
# variables.h5                                   2024-08-01 00:45:50        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:45:51           64
# config.json                                    2024-08-01 00:45:51         2589
# variables.h5                                   2024-08-01 00:45:51        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 00:45:50           64
# config.json                                    2024-08-01 00:45:50         2589
# variables.h5                                   2024-08-01 00:45:50        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 2.15 s, sys: 1.46 s, total: 3.61 s
# Wall time: 3h 19min 38s

# %%
homogeneous_rewards_filename = "checkpoints/homogeneous_rewards-sigma.pkl"
with open(homogeneous_rewards_filename, 'wb') as file:
    pickle.dump(homogeneous_rewards_dict, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(homogeneous_rewards_filename, "rb") as file:
    homogeneous_rewards_dict = pickle.load(file)

# %%
plot_rewards_dict(homogeneous_rewards_dict, "homogeneous")

# %% [markdown]
# # Simulation 2: Heterogeneous Users, Linear Baseline, No Time Effects

# %%
# %%time
heterogeneous_rewards_dict = run_simulation(heterogeneous_data_generator, heterogeneous_featurizer_nn_model, n_jobs=n_jobs)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layersKeras model archive loading:
#
# ......dense
# .........vars
# ............0
# File Name                                             Modified             Size
# ............1metadata.json                                  2024-08-01 01:51:16           64
#
# config.json                                    2024-08-01 01:51:16         2591
# ......dense_1variables.h5                                   2024-08-01 01:51:16        19128
#
# .........vars
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
#
# ............1
# ...layers...layers
#
# ......dense_2
# ......dense......denseKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# .........vars
#
#
# .........vars............0.........vars
#
# File Name                                             Modified             Size
#
# ............0............0............1
# metadata.json                                  2024-08-01 01:51:16           64
#
#
# ......dense_3............1............1
# config.json                                    2024-08-01 01:51:16         2591
#
#
# .........vars......dense_1......dense_1
# variables.h5                                   2024-08-01 01:51:16        19128
#
#
# ............0.........vars.........vars
#
#
# ............1............0............0
#
#
# ......input_layer............1.........vars............1
#
#
# ......dense_2......dense_2
#
#
# ...vars.........vars
# .........vars
#
# ............0............0
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1............1
#
#
# Keras model archive loading:
# ...layers......dense_3......dense_3
#
#
# ......denseFile Name                                             Modified             Size
# .........vars.........vars
#
#
# .........varsmetadata.json                                  2024-08-01 01:51:16           64
#
# ............0............0config.json                                    2024-08-01 01:51:16         2591
#
# ............0variables.h5                                   2024-08-01 01:51:16        19128
#
#
# ............1............1
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ......input_layer......input_layerFile Name                                             Modified             Size
#
# ......dense_1
# metadata.json                                  2024-08-01 01:51:16           64
# .........vars
#
# .........varsconfig.json                                    2024-08-01 01:51:16         2591
# .........vars...vars
#
# variables.h5                                   2024-08-01 01:51:16        19128
#
# ............0...vars
#
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1
#
# ...layers......input_layer
#
# ......dense
# Keras model archive loading:
# .........varsFile Name                                             Modified             Size
# .........vars
#
# ...varsmetadata.json                                  2024-08-01 01:51:16           64
#
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras model archive loading:
# ...layersKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
# ......dense............0
# Keras model archive loading:
#
# metadata.json                                  2024-08-01 01:51:16           64
# .........vars
# ............1
# File Name                                             Modified             Size
# ............0......dense_1metadata.json                                  2024-08-01 01:51:16           64
#
# config.json                                    2024-08-01 01:51:16         2591
# config.json                                    2024-08-01 01:51:16         2591
# .........varsvariables.h5                                   2024-08-01 01:51:16        19128
# variables.h5                                   2024-08-01 01:51:16        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:17        19128
#
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............1
# ......dense_2
# ............1.........varsKeras model archive loading:
#
# ......dense_1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
#
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# Keras model archive saving:
# .........varsFile Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# config.json                                    2024-08-01 01:51:16         2591
#
# variables.h5                                   2024-08-01 01:51:17        19128
# variables.h5                                   2024-08-01 01:51:16        19128
# ............0...layers
#
# ............1
#
# ......dense......dense_2
# .........vars
#
# .........vars
# ............0metadata.json                                  2024-08-01 01:51:16           64
# ............0
#
#
# ............0Keras model archive loading:
# ............1............1
#
# ............1File Name                                             Modified             Size
# ......dense_3
# ......dense_3
# .........vars
# ............0......dense_1
#
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-08-01 01:51:16         2591
#
#
# variables.h5                                   2024-08-01 01:51:16        19128
# ............0............0...layers
#
# ............1............1
#
#
# ......input_layer......dense_2
# ......dense.........vars
#
# .........vars
#
# .........vars............0
# ............0...vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
#
# ............1config.json                                    2024-08-01 01:51:17         2591
# ............1variables.h5                                   2024-08-01 01:51:17        19128
#
# ......dense_3
# .........vars
# ............0
#
# ............1
#
# ...layers
# ......input_layer......input_layerKeras model archive loading:
# ......dense_1
#
# File Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 01:51:16           64
# .........vars......denseconfig.json                                    2024-08-01 01:51:16         2591
# .........vars
#
# ............0
# .........varsvariables.h5                                   2024-08-01 01:51:16        19128
#
# .........vars
#
#
# ............0...vars
# ............1
# ............1
# ......dense_2......dense_1
#
#
# ...vars.........vars.........vars
#
#
# ............0............0
#
# ............1............1
#
# ......dense_2......dense_3
#
# .........vars.........vars
#
# ............0............0
# ............1
#
# ......input_layerKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# .........vars
#
# ...layers
# ......denseKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# ............1config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
#
#
# .........vars......dense_3
#
# ...vars.........vars............0
# Keras model archive loading:
#
#
# ............1File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
# ......dense_1config.json                                    2024-08-01 01:51:16         2591
#
# ...layers............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:variables.h5                                   2024-08-01 01:51:16        19128
#
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
#
# .........vars
# ...layers......dense
#
#
# ......input_layerKeras model archive loading:
# ............0.........vars......denseFile Name                                             Modified             Size
#
#
#
# ............0metadata.json                                  2024-08-01 01:51:16           64
# ............1
# .........vars
#
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
#
# .........vars......dense_2............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# ......dense_1variables.h5                                   2024-08-01 01:51:17        19128
# ............0
#
# .........varsKeras model archive loading:
# .........vars
# ...vars
# ............1............0
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
#
# ............0metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# metadata.json                                  2024-08-01 01:51:16           64
# variables.h5                                   2024-08-01 01:51:17        19128
# config.json                                    2024-08-01 01:51:16         2591
#
#
# ............1......dense_1............1
#
# Keras model archive loading:
#
# ......dense_3File Name                                             Modified             Size
# ......dense_2metadata.json                                  2024-08-01 01:51:16           64
# variables.h5                                   2024-08-01 01:51:16        19128
# .........vars
#
#
# .........vars............0
#
# .........vars............1
# ......dense_2
# .........vars
# ............0............0
# ............1
#
# ......input_layer............1
#
#
# ............0
# ............1.........vars......dense_3
#
# .........vars
# ......dense_3
# ...vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
# .........varsconfig.json                                    2024-08-01 01:51:16         2591
# ............1
# variables.h5                                   2024-08-01 01:51:16        19128
#
# Keras model archive loading:
# ...layers......input_layerFile Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
# variables.h5                                   2024-08-01 01:51:16        19128
#
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers......dense
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# ............0config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...vars
#
# Keras model archive loading:
#
#
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# metadata.json                                  2024-08-01 01:51:16           64
# ............1File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:16         2591
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
# variables.h5                                   2024-08-01 01:51:16        19128
#
# ............0Keras model archive loading:
# ......dense_1File Name                                             Modified             Size
#
# ............1metadata.json                                  2024-08-01 01:51:16           64
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers......dense
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ......input_layerKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
# config.json                                    2024-08-01 01:51:16         2591
#
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:Keras model archive loading:
#
# File Name                                             Modified             Size
# .........vars.........vars...layers
# variables.h5                                   2024-08-01 01:51:16        19128
#
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:16         2591
#
# ...vars
#
#
# ......dense
# ......densevariables.h5                                   2024-08-01 01:51:16        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ...layersmetadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
# .........vars............0
#
#
# ...layers............0
# ......denseKeras model archive loading:
#
# .........vars
# ............0............1
# File Name                                             Modified             Size
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# ......dense
# metadata.json                                  2024-08-01 01:51:16           64
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:17        19128
# ............0
# config.json                                    2024-08-01 01:51:16         2591
# ......dense_2............1
#
#
# .........vars......dense_1Keras model archive loading:
#
#
# ............0File Name                                             Modified             Size
#
# .........vars............1
# .........vars
# ......dense_1
#
# ............0............0.........varsmetadata.json                                  2024-08-01 01:51:16           64
#
# ............0config.json                                    2024-08-01 01:51:16         2591
#
#
# ............1variables.h5                                   2024-08-01 01:51:16        19128
#
#
# variables.h5                                   2024-08-01 01:51:16        19128
# ............1............0
# ............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ......dense_2............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:17           64
# config.json                                    2024-08-01 01:51:17         2591
# variables.h5                                   2024-08-01 01:51:18        19128
# ......dense_1
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1............1
#
#
#
# ......dense_1............0
#
#
# ...layers
# ......dense_2......dense
#
# .........vars.........vars.........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............1............0
# ............0......dense_3
#
#
# Keras model archive loading:
# ............0.........vars............1
#
#
# ............1......dense_3
#
# ......dense_2.........vars
#
# ............0............1.........vars.........vars
#
#
# ............1............1......input_layer
#
#
# ......dense_1File Name                                             Modified             Size
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# .........vars
# Keras model archive saving:
# File Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 01:51:18           64
#
# ............0config.json                                    2024-08-01 01:51:18         2591
# .........varsvariables.h5                                   2024-08-01 01:51:18        19128
#
#
#
# metadata.json                                  2024-08-01 01:51:16           64
# ............0............1...layers
# ......dense_1............0
# ......input_layerKeras model archive loading:
#
# ............1
#
# File Name                                             Modified             Size
# config.json                                    2024-08-01 01:51:16         2591
# ...vars
#
# .........vars
#
# .........vars.........varsvariables.h5                                   2024-08-01 01:51:18        19128
# metadata.json                                  2024-08-01 01:51:18           64
# ......dense............1......dense_3
#
#
#
# config.json                                    2024-08-01 01:51:18         2591
# variables.h5                                   2024-08-01 01:51:18        19128
# .........vars............0......dense_2...vars
# .........vars.........vars
#
#
#
# ............0
#
#
# ......dense_3............0............0............1
# ......dense_3............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
#
#
#
# ............1............1.........vars.........vars......dense_2............0
#
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:18           64
# config.json                                    2024-08-01 01:51:18         2591
# variables.h5                                   2024-08-01 01:51:18        19128
#
#
#
#
# ......input_layer
# ......dense_2Keras model archive loading:
# ............0............0
# .........vars............1
#
# .........varsFile Name                                             Modified             Size
#
# ......dense_1............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:............1
#
# ......dense_3
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:.........vars
# ............0
#
# ............1
# .........vars
# metadata.json                                  2024-08-01 01:51:18           64
#
# ......dense_2............1............1.........vars............0
#
#
# .........vars
# ............1
#
# ......input_layer
# ............0config.json                                    2024-08-01 01:51:18         2591
# .........vars
#
# ............0
# ...layers............1
# ......dense_3...layers
# variables.h5                                   2024-08-01 01:51:18        19128
# .........vars...vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 01:51:18           64
# config.json                                    2024-08-01 01:51:18         2591
# ......densevariables.h5                                   2024-08-01 01:51:18        19128
# ...vars
#
# ............0
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......input_layer
# ......input_layer
#
# .........vars
# ...vars............1
#
# .........vars...layers
#
# ......dense......input_layer
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# .........vars.........vars
# ...vars
#
# ...vars
#
# ............0......dense...layers
#
# .........vars.........vars
#
# ............1......dense_3
# ......dense
# .........vars............0
#
# .........vars............0
#
# ............0
# ............1
# ......dense_1
#
#
#
# ......dense_1.........vars
# ............1............0
#
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......input_layer
# .........vars............1
# ............0
# ...layers
#
#
# ............1......dense_1
# ............0
# ......dense......dense_2
# .........vars
# ......dense_1
# ............1
# .........vars
# .........vars
#
# ......dense_2
#
# .........vars
# .........vars.........vars
# ............0
#
#
# ...vars............0
# ............0
# ............1............0............1
#
# ......dense_1............0
#
# ............1
#
# .........vars............1......dense_3............1
# .........vars
#
#
# ......dense_2............0
#
# ............0
#
#
# .........vars......dense_3......dense_2
# ............1............1
#
#
#
# .........vars......dense_2.........vars
#
# ............0
# ............0.........vars
# ............0
# ............0
# ............1
#
# ......dense_3
#
# ............1............1
# ......input_layer............1
# ......dense_3
#
# ......dense_3
#
# .........vars
# ......input_layer.........vars............0
# ............1
# .........vars
# ......input_layer
#
# .........vars.........vars
# ............0.........vars
#
# ...vars
#
# ............0...vars............1
# ...vars
#
#
#
# ............1......input_layer
#
# ......input_layer.........vars
#
# .........vars...vars
#
# ...vars
# Keras model archive loading:
# metadata.json                                  2024-08-01 01:51:18           64
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:51:54           64
# config.json                                    2024-08-01 03:51:54         2591
# variables.h5                                   2024-08-01 03:51:54        19128
# config.json                                    2024-08-01 01:51:18         2591
# variables.h5                                   2024-08-01 01:51:18        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:27           64
# config.json                                    2024-08-01 03:52:27         2591
# variables.h5                                   2024-08-01 03:52:27        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:51:54           64
# config.json                                    2024-08-01 03:51:54         2591
# variables.h5                                   2024-08-01 03:51:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:39           64
# config.json                                    2024-08-01 03:52:39         2591
# variables.h5                                   2024-08-01 03:52:39        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:26           64
# config.json                                    2024-08-01 03:52:26         2591
# variables.h5                                   2024-08-01 03:52:26        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:40           64
# Keras model archive loading:
# config.json                                    2024-08-01 03:52:40         2591
# variables.h5                                   2024-08-01 03:52:40        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:38           64
# config.json                                    2024-08-01 03:52:38         2591
# variables.h5                                   2024-08-01 03:52:38        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:47           64
# config.json                                    2024-08-01 03:52:47         2591
# variables.h5                                   2024-08-01 03:52:47        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:40           64
# config.json                                    2024-08-01 03:52:40         2591
# variables.h5                                   2024-08-01 03:52:40        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:54           64
# config.json                                    2024-08-01 03:52:54         2591
# variables.h5                                   2024-08-01 03:52:54        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:46           64
# config.json                                    2024-08-01 03:52:46         2591
# variables.h5                                   2024-08-01 03:52:46        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# metadata.json                                  2024-08-01 03:52:54           64
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:54           64
# config.json                                    2024-08-01 03:52:54         2591
# variables.h5                                   2024-08-01 03:52:54        19128
# config.json                                    2024-08-01 03:52:54         2591
# variables.h5                                   2024-08-01 03:52:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............0
# ............1
#
# ...layers
# ......dense_1
# ......dense.........vars
#
# ............0
# ............1.........vars
# ............0
#
# ......dense_2............1
#
# ......dense_1
# .........vars
# ............0.........vars
#
# ............1
# ............0
# ............1......dense_2
#
# ......dense_3.........vars
#
# ............0.........vars
#
# ............1............0
#
# ......dense_3
# .........vars
# ............1............0
# ......input_layer
# .........vars
#
# ............1...vars
#
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:01           64
# config.json                                    2024-08-01 03:53:01         2591
# variables.h5                                   2024-08-01 03:53:01        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:52:54           64
# config.json                                    2024-08-01 03:52:54         2591
# variables.h5                                   2024-08-01 03:52:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:08           64
# config.json                                    2024-08-01 03:53:08         2591
# variables.h5                                   2024-08-01 03:53:08        19128
# metadata.json                                  2024-08-01 03:53:00           64
# config.json                                    2024-08-01 03:53:00         2591
# variables.h5                                   2024-08-01 03:53:00        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:11           64
# config.json                                    2024-08-01 03:53:11         2591
# ...
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:17           64
# config.json                                    2024-08-01 03:53:17         2591
# variables.h5                                   2024-08-01 03:53:17        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:14           64
# config.json                                    2024-08-01 03:53:14         2591
# variables.h5                                   2024-08-01 03:53:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:18           64
# config.json                                    2024-08-01 03:53:18         2591
# variables.h5                                   2024-08-01 03:53:18        19128
# ............1metadata.json                                  2024-08-01 03:53:16           64
#
# config.json                                    2024-08-01 03:53:16         2591
# variables.h5                                   2024-08-01 03:53:16        19128
# ......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:18           64
# config.json                                    2024-08-01 03:53:18         2591
# variables.h5                                   2024-08-01 03:53:18        19128
# .........varsKeras model archive loading:
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# ...varsmetadata.json                                  2024-08-01 03:53:18           64
#
# ...layers
#
# config.json                                    2024-08-01 03:53:18         2591
# ......densevariables.h5                                   2024-08-01 03:53:18        19128
#
# .........vars
# ............0
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ......dense_1...layers
#
# ......dense.........vars
# .........vars
#
# ............0............0
#
# ............1............1
# ......dense_2
# ......dense_1
#
# .........vars
# .........vars............0
#
# ............0............1
#
# ............1......dense_3
# ......dense_2
#
# .........vars
# ............0
# .........vars............1
# ......dense_3
# ............0
#
# .........vars............1
#
# ............0
# ......input_layer............1
#
# .........vars......input_layer
#
# .........vars...vars
#
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:49           64
# config.json                                    2024-08-01 03:53:49         2591
# variables.h5                                   2024-08-01 03:53:50        19128
# metadata.json                                  2024-08-01 03:53:18           64
# config.json                                    2024-08-01 03:53:18         2591
# variables.h5                                   2024-08-01 03:53:18        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:55:39           64
# config.json                                    2024-08-01 03:55:39         2591
# variables.h5                                   2024-08-01 03:55:39        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:53:48           64
# config.json                                    2024-08-01 03:53:48         2591
# variables.h5                                   2024-08-01 03:53:50        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:57:12           64
# File Name                                             Modified             Size
# config.json                                    2024-08-01 03:57:12         2591
# variables.h5                                   2024-08-01 03:57:12        19128
# metadata.json                                  2024-08-01 03:55:38           64
# config.json                                    2024-08-01 03:55:38         2591
# variables.h5                                   2024-08-01 03:55:38        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:59:36           64
# config.json                                    2024-08-01 03:59:36         2591
# variables.h5                                   2024-08-01 03:59:36        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:57:12           64
# config.json                                    2024-08-01 03:57:12         2591
# variables.h5                                   2024-08-01 03:57:12        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:00:12           64
# config.json                                    2024-08-01 04:00:12         2591
# variables.h5                                   2024-08-01 04:00:12        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 03:59:36           64
# config.json                                    2024-08-01 03:59:36         2591
# variables.h5                                   2024-08-01 03:59:36        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:03:10           64
# config.json                                    2024-08-01 04:03:10         2591
# variables.h5                                   2024-08-01 04:03:10        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:00:12           64
# config.json                                    2024-08-01 04:00:12         2591
# variables.h5                                   2024-08-01 04:00:12        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:03:50           64
# config.json                                    2024-08-01 04:03:50         2591
# variables.h5                                   2024-08-01 04:03:50        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:03:10           64
# config.json                                    2024-08-01 04:03:10         2591
# variables.h5                                   2024-08-01 04:03:10        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:04:01           64
# config.json                                    2024-08-01 04:04:01         2591
# variables.h5                                   2024-08-01 04:04:01        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:03:50           64
# config.json                                    2024-08-01 04:03:50         2591
# variables.h5                                   2024-08-01 04:03:50        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:04:00           64
# config.json                                    2024-08-01 04:04:00         2591
# variables.h5                                   2024-08-01 04:04:00        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 2.13 s, sys: 1.58 s, total: 3.71 s
# Wall time: 2h 52min 26s

# %%
heterogeneous_rewards_filename = "checkpoints/heterogeneous_rewards-sigma.pkl"
with open(heterogeneous_rewards_filename, 'wb') as file:
    pickle.dump(heterogeneous_rewards_dict, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(heterogeneous_rewards_filename, "rb") as file:
    heterogeneous_rewards_dict = pickle.load(file)

# %%
plot_rewards_dict(heterogeneous_rewards_dict, "heterogeneous")

# %% [markdown]
# # Simulation 3: Nonlinear Baseline and User-/Time-specific Effects

# %%
# %%time
nonlinear_rewards_dict = run_simulation(nonlinear_data_generator, nonlinear_featurizer_nn_model, n_jobs=n_jobs)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:44           64
# config.json                                    2024-08-01 04:43:44         2591
# variables.h5                                   2024-08-01 04:43:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:44           64
# config.json                                    2024-08-01 04:43:44         2591
# variables.h5                                   2024-08-01 04:43:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:44           64
# config.json                                    2024-08-01 04:43:44         2591
# variables.h5                                   2024-08-01 04:43:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# Keras model archive loading:
# ............1
# File Name                                             Modified             Size
# ......dense_1
# metadata.json                                  2024-08-01 04:43:44           64
# config.json                                    2024-08-01 04:43:44         2591
# .........vars
# variables.h5                                   2024-08-01 04:43:44        19128
# ............0
# ............1
# ......dense_2
# .........vars
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ............1...layers
#
# ......dense_3......dense
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# .........vars
# File Name                                             Modified             Size
# ............0............0
# metadata.json                                  2024-08-01 04:43:45           64
#
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# ............1
# ............1......input_layer
#
# ......dense_1.........vars
#
# .........vars...vars
#
# ............0
# ............1
# ......dense_2
# .........varsKeras model archive loading:
#
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# ............1
# metadata.json                                  2024-08-01 04:43:44           64
#
# config.json                                    2024-08-01 04:43:44         2591
# ...layers......dense_3variables.h5                                   2024-08-01 04:43:44        19128
#
#
# .........vars......dense
#
# ............0.........vars
#
# ............1............0
#
# ......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1
# .........varsFile Name                                             Modified             Size
#
# ......dense_1...varsmetadata.json                                  2024-08-01 04:43:45           64
#
#
# .........varsconfig.json                                    2024-08-01 04:43:45         2591
#
# ............0
# variables.h5                                   2024-08-01 04:43:45        19128
# ............1
# ......dense_2
# .........vars
# ............0Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ............1...layers
#
# Keras model archive loading:
# ......dense_3
# ......dense.........vars
#
# File Name                                             Modified             Size
# .........vars............0metadata.json                                  2024-08-01 04:43:44           64
#
#
# config.json                                    2024-08-01 04:43:44         2591
# ............0variables.h5                                   2024-08-01 04:43:44        19128
# ............1
#
# ......input_layer............1
#
# .........vars......dense_1
#
# ...vars
# .........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ............0metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
#
# Keras model archive loading:
# File Name                                             Modified             Size
# ............1metadata.json                                  2024-08-01 04:43:44           64
# config.json                                    2024-08-01 04:43:44         2591
#
# ......dense_2variables.h5                                   2024-08-01 04:43:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
#
# .........varsKeras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
#
# ...layersKeras model archive saving:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# ......denseconfig.json                                    2024-08-01 04:43:45         2591
#
# variables.h5                                   2024-08-01 04:43:45        19128
# .........vars
# ............0
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras model archive loading:
# ............1............0
#
# ...layersFile Name                                             Modified             Size
# Keras model archive loading:
#
# metadata.json                                  2024-08-01 04:43:44           64
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# config.json                                    2024-08-01 04:43:44         2591
# ......dense
# ......dense_1File Name                                             Modified             Size
# variables.h5                                   2024-08-01 04:43:44        19128
# File Name                                             Modified             Size
#
# ......dense_3...layers
# .........varsmetadata.json                                  2024-08-01 04:43:44           64
#
#
# metadata.json                                  2024-08-01 04:43:44           64
#
# config.json                                    2024-08-01 04:43:44         2591
# config.json                                    2024-08-01 04:43:44         2591
# .........vars......dense............0
# variables.h5                                   2024-08-01 04:43:44        19128
# variables.h5                                   2024-08-01 04:43:44        19128
# ............0
#
# ............1
# ............1......dense_2
#
# .........vars
# ............0.........vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# ............0.........vars
#
# ............0
# ............1......input_layer
#
# ............1
# ............1......dense_1.........vars
#
# File Name                                             Modified             Size
#
# ...vars......dense_3
#
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# .........vars
# .........varsvariables.h5                                   2024-08-01 04:43:45        19128
# ............0
#
# ............0............1
#
# ............1......dense_2
#
# ......input_layer.........vars
# ............0
# ............1
# ......dense_3
# Keras model archive loading:
# .........vars
# File Name                                             Modified             Size
# ............0
#
#
# ......dense_1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# .........vars............1metadata.json                                  2024-08-01 04:43:44           64
#
# config.json                                    2024-08-01 04:43:44         2591
# variables.h5                                   2024-08-01 04:43:44        19128
# ...vars
#
# ......input_layer......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# .........vars
# ...varsFile Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# .........vars
# ............0
#
# ............1
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
# Keras model archive loading:
# ......dense_2Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 04:43:44           64
# File Name                                             Modified             Size
# config.json                                    2024-08-01 04:43:44         2591
# variables.h5                                   2024-08-01 04:43:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# metadata.json                                  2024-08-01 04:43:44           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# variables.h5                                   2024-08-01 04:43:45        19128
#
# ...layers.........vars
#
# config.json                                    2024-08-01 04:43:44         2591
# ...layersKeras model archive loading:
# ............0
# ...layersvariables.h5                                   2024-08-01 04:43:44        19128
#
# ......dense
#
#
# ......dense......denseKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# .........vars
#
# ............1
#
#
# metadata.json                                  2024-08-01 04:43:44           64
# config.json                                    2024-08-01 04:43:44         2591
# ...layersKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# variables.h5                                   2024-08-01 04:43:44        19128
# .........vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ......dense
# metadata.json                                  2024-08-01 04:43:45           64
# config.json                                    2024-08-01 04:43:45         2591
# .........varsvariables.h5                                   2024-08-01 04:43:46        19128
# ............0
# ............0Keras model archive loading:
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 04:43:44           64
#
# ............1config.json                                    2024-08-01 04:43:44         2591
# ............0......dense_3variables.h5                                   2024-08-01 04:43:46        19128
#
# ............1
# ............1
# ......dense_1.........vars
#
# ............0
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense_1......dense......dense_1.........vars
#
# ............1
# .........vars
#
# ............0...layersKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# .........vars
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
#
#
# .........varsvariables.h5                                   2024-08-01 04:43:46        19128
# ......dense
# ............0
#
# ............1.........vars............0
#
#
# .........vars
# ............1............1
# ......dense_1............0
#
#
#
#
# ......input_layer......dense_2......dense_2............0............0.........vars
#
#
#
#
# .........vars
# ............0............1............1.........vars
#
#
#
#
# ............1...vars............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ......dense_2......dense_1
#
# .........vars
# ......dense_1
# ......dense_2.........vars...layers
#
# Keras model archive loading:
# ............0............0
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# variables.h5                                   2024-08-01 04:43:46        19128
# File Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 04:43:46           64
# .........varsconfig.json                                    2024-08-01 04:43:46         2591
#
#
# variables.h5                                   2024-08-01 04:43:46        19128
# .........vars
#
# ............0......dense
# ............0
# ............1
#
# ............1
#
# ............1
# ......dense_3............1File Name                                             Modified             Size
# ............0
#
# metadata.json                                  2024-08-01 04:43:46           64
# ......dense_3config.json                                    2024-08-01 04:43:46         2591
#
# .........vars
# ............1.........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense_3
#
#
# ............0
#
# ......dense_3.........vars.........vars
#
#
# .........vars............0
#
#
# .........vars............1......dense_2............1............0
# ...layersKeras model archive loading:
#
#
# ............0.........vars
#
# ......dense_2Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# ......dense
# ............1
#
# ............1
# ............0............0File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
#
# ............1
# ......input_layer
# ......input_layer.........vars
# Keras model archive loading:
#
#
# ......input_layer
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
#
# File Name                                             Modified             Size
# ............0metadata.json                                  2024-08-01 04:43:46           64
# ............1config.json                                    2024-08-01 04:43:46         2591
#
# variables.h5                                   2024-08-01 04:43:46        19128
#
# .........vars.........vars
#
#
#
# ...vars...vars...vars
# ......input_layer
#
#
# File Name                                             Modified             Size
# ............1
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# .........varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 04:43:46           64
# ......dense_1config.json                                    2024-08-01 04:43:46         2591
#
# variables.h5                                   2024-08-01 04:43:46        19128
# Keras model archive loading:
# .........vars...varsFile Name                                             Modified             Size
#
# metadata.json                                  2024-08-01 04:43:46           64
#
# config.json                                    2024-08-01 04:43:46         2591
#
# variables.h5                                   2024-08-01 04:43:46        19128
# metadata.json                                  2024-08-01 04:43:46           64
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# ......dense_3
# .........vars
# ............0............0
#
# Keras model archive loading:
# ............0File Name                                             Modified             Size
# Keras model archive loading:
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
#
# variables.h5                                   2024-08-01 04:43:46        19128
# config.json                                    2024-08-01 04:43:46         2591
# ............1Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# ............1File Name                                             Modified             Size
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# metadata.json                                  2024-08-01 04:43:46           64
# variables.h5                                   2024-08-01 04:43:46        19128
# ............1
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# Keras model archive loading:
# ......dense_3File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
#
# variables.h5                                   2024-08-01 04:43:46        19128
# .........vars
# ............0
#
#
# ......input_layer............1
#
# .........vars
#
# ......dense_2...vars
#
# ............0.........vars
#
# ............1
# ......input_layer
# ............0.........vars
#
# ............1...vars
# ......dense_3Keras model archive loading:
#
#
# .........varsFile Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
#
# ............0............1
#
# ............1......dense_3
#
# ......input_layer.........vars
#
# .........vars............0
#
# ............1...vars
#
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ......input_layer
# metadata.json                                  2024-08-01 04:43:46           64
# .........vars
# config.json                                    2024-08-01 04:43:46         2591
# ...varsvariables.h5                                   2024-08-01 04:43:46        19128
#
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# ...layers
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# ......dense
# variables.h5                                   2024-08-01 04:43:46        19128
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:config.json                                    2024-08-01 04:43:46         2591
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:...layers
#
#
# ...layers............0...layersvariables.h5                                   2024-08-01 04:43:46        19128
# ......dense
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
#
# ............1
#
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......denseKeras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense_3
# .........vars
#
#
# ...layers.........vars
# ......dense
# ............0...layers
# .........vars
#
# ............0
# ............0
#
# ............1......dense
# ............0............1
#
# .........vars
#
# ...layers
# ............1
#
# ...layers......dense_1
# ............1......dense_1
# ............0
#
# .........vars
#
# .........vars......input_layer
# ............0
#
# .........vars
# ......dense...vars
# ............1
# ......dense............0
#
#
# .........vars............1Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:......dense_2............1......dense
#
#
#
# ............0
#
#
# .........vars
# ......dense_1.........vars...layers
#
#
# .........vars............0
# ......dense
#
# ............0
#
# ............0......dense_1
# ............1
# ............1............1
#
#
# ......dense_1
# .........vars......dense_1.........vars.........vars
# ......dense_2
# ............0
#
# ............0
#
# ............0............1
#
# .........vars............1
#
# ............1
#
# ......dense_2............0......dense_2
# .........vars
#
# .........vars
# .........vars
#
# ......dense_1............1............0......dense_2
# ............1............0
#
# .........vars
# .........vars......dense_3
#
#
# ............0
#
# ......dense_1............1
# .........vars
#
#
# .........vars.........vars............1
# ............0
# ......dense_3
# ............0............0
#
# ............0............1............1
#
#
#
# ............0
# ......dense_3
#
# .........vars......dense_2......dense_3............1............1
# ............1
#
#
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ............1
#
# ......dense_2............0.........vars......dense_2......dense_3
# .........vars.........vars
#
# .........vars
#
#
# ............0............0
#
# ............0
# ............1.........vars...layers
#
#
# ............0............1
#
# ......input_layer
#
# ......dense
#
# .........vars......input_layer
#
#
# ......input_layer............0............1............0
#
# .........vars............1
# .........vars............1
#
# ............1
#
#
#
# ...vars
#
# ...vars.........vars......dense_3
# ............1...vars......dense_3
#
#
#
# .........vars
#
# ......dense_3.........vars............0
#
# ......input_layer.........vars
# ............0
# ............1.........vars
#
# ......input_layer
#
# ............0............1.........vars
#
# ............1
# ...vars
# ............0......input_layer
#
# .........vars
# ......input_layer...vars
# .........vars............1
#
#
# .........vars
#
# ......dense_1
# ......input_layer...vars
# ...vars
#
#
# .........vars.........vars
#
# ............0...vars
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
#
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 04:43:46           64
# config.json                                    2024-08-01 04:43:46         2591
# variables.h5                                   2024-08-01 04:43:46        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:44:37           64
# config.json                                    2024-08-01 06:44:37         2591
# variables.h5                                   2024-08-01 06:44:37        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3Keras model archive loading:
#
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:44:36           64
# config.json                                    2024-08-01 06:44:36         2591
# .........varsKeras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# variables.h5                                   2024-08-01 06:44:36        19128
#
# ............0File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:44:38           64
# config.json                                    2024-08-01 06:44:38         2591
# variables.h5                                   2024-08-01 06:44:38        19128
#
# ............1
# ......input_layer
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# .........vars...layers
# ...vars
# ......dense
#
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:40           64
# config.json                                    2024-08-01 06:45:40         2591
# variables.h5                                   2024-08-01 06:45:40        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:44:38           64
# config.json                                    2024-08-01 06:44:38         2591
# variables.h5                                   2024-08-01 06:44:38        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:41           64
# Keras model archive loading:
# config.json                                    2024-08-01 06:45:41         2591
# variables.h5                                   2024-08-01 06:45:41        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:40           64
# config.json                                    2024-08-01 06:45:40         2591
# variables.h5                                   2024-08-01 06:45:40        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:42           64
# File Name                                             Modified             Size
# config.json                                    2024-08-01 06:45:42         2591
# variables.h5                                   2024-08-01 06:45:42        19128
# metadata.json                                  2024-08-01 06:45:40           64
# config.json                                    2024-08-01 06:45:40         2591
# variables.h5                                   2024-08-01 06:45:40        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:43           64
# config.json                                    2024-08-01 06:45:43         2591
# variables.h5                                   2024-08-01 06:45:43        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:42           64
# config.json                                    2024-08-01 06:45:42         2591
# variables.h5                                   2024-08-01 06:45:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:45:42           64
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:06           64
# config.json                                    2024-08-01 06:46:06         2591
# variables.h5                                   2024-08-01 06:46:06        19128
# config.json                                    2024-08-01 06:45:42         2591
# variables.h5                                   2024-08-01 06:45:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# metadata.json                                  2024-08-01 06:46:06           64
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:10           64
# config.json                                    2024-08-01 06:46:10         2591
# variables.h5                                   2024-08-01 06:46:10        19128
# config.json                                    2024-08-01 06:46:06         2591
# variables.h5                                   2024-08-01 06:46:06        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:22           64
# config.json                                    2024-08-01 06:46:22         2591
# variables.h5                                   2024-08-01 06:46:22        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:10           64
# config.json                                    2024-08-01 06:46:10         2591
# variables.h5                                   2024-08-01 06:46:10        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:26           64
# config.json                                    2024-08-01 06:46:26         2591
# ...
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:29           64
# Keras model archive loading:
# config.json                                    2024-08-01 06:46:29         2591
# variables.h5                                   2024-08-01 06:46:29        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:28           64
# config.json                                    2024-08-01 06:46:28         2591
# variables.h5                                   2024-08-01 06:46:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:30           64
# config.json                                    2024-08-01 06:46:30         2591
# variables.h5                                   2024-08-01 06:46:30        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:28           64
# config.json                                    2024-08-01 06:46:28         2591
# variables.h5                                   2024-08-01 06:46:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:34           64
# config.json                                    2024-08-01 06:46:34         2591
# Keras model archive loading:
# variables.h5                                   2024-08-01 06:46:34        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:30           64
# config.json                                    2024-08-01 06:46:30         2591
# variables.h5                                   2024-08-01 06:46:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:44           64
# config.json                                    2024-08-01 06:46:44         2591
# variables.h5                                   2024-08-01 06:46:44        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:34           64
# config.json                                    2024-08-01 06:46:34         2591
# variables.h5                                   2024-08-01 06:46:34        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# Keras model archive loading:
# metadata.json                                  2024-08-01 06:48:19           64
# config.json                                    2024-08-01 06:48:19         2591
# variables.h5                                   2024-08-01 06:48:19        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:46:44           64
# config.json                                    2024-08-01 06:46:44         2591
# variables.h5                                   2024-08-01 06:46:44        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:50:30           64
# config.json                                    2024-08-01 06:50:30         2591
# variables.h5                                   2024-08-01 06:50:30        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:48:18           64
# config.json                                    2024-08-01 06:48:18         2591
# variables.h5                                   2024-08-01 06:48:18        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# Keras model archive loading:
# metadata.json                                  2024-08-01 06:52:42           64
# config.json                                    2024-08-01 06:52:42         2591
# variables.h5                                   2024-08-01 06:52:42        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:50:30           64
# config.json                                    2024-08-01 06:50:30         2591
# variables.h5                                   2024-08-01 06:50:30        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:53:55           64
# config.json                                    2024-08-01 06:53:55         2591
# variables.h5                                   2024-08-01 06:53:55        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:52:42           64
# config.json                                    2024-08-01 06:52:42         2591
# variables.h5                                   2024-08-01 06:52:42        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:57:28           64
# config.json                                    2024-08-01 06:57:28         2591
# variables.h5                                   2024-08-01 06:57:28        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:53:54           64
# config.json                                    2024-08-01 06:53:54         2591
# variables.h5                                   2024-08-01 06:53:54        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:58:14           64
# config.json                                    2024-08-01 06:58:14         2591
# variables.h5                                   2024-08-01 06:58:14        19128
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:57:28           64
# config.json                                    2024-08-01 06:57:28         2591
# variables.h5                                   2024-08-01 06:57:28        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# Keras model archive loading:
# metadata.json                                  2024-08-01 06:59:17           64
# config.json                                    2024-08-01 06:59:17         2591
# variables.h5                                   2024-08-01 06:59:17        19128
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:58:14           64
# config.json                                    2024-08-01 06:58:14         2591
# variables.h5                                   2024-08-01 06:58:14        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2024-08-01 06:59:16           64
# config.json                                    2024-08-01 06:59:16         2591
# variables.h5                                   2024-08-01 06:59:16        19128
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......dense
# .........vars
# ............0
# ............1
# ......dense_1
# .........vars
# ............0
# ............1
# ......dense_2
# .........vars
# ............0
# ............1
# ......dense_3
# .........vars
# ............0
# ............1
# ......input_layer
# .........vars
# ...vars
# CPU times: user 2.1 s, sys: 1.79 s, total: 3.9 s
# Wall time: 3h 10min 36s

# %%
nonlinear_rewards_filename = "checkpoints/nonlinear_rewards-sigma.pkl"
with open(nonlinear_rewards_filename, 'wb') as file:
    pickle.dump(nonlinear_rewards_dict, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(nonlinear_rewards_filename, "rb") as file:
    nonlinear_rewards_dict = pickle.load(file)

# %%
plot_rewards_dict(nonlinear_rewards_dict, "nonlinear")

# %% [markdown]
# # Cumulative Regret for All Three Settings

# %% [markdown]
# ## Calculations

# %%
# Calculate incremental regret
incremental_homogeneous_regret_dict = {
    method_name: get_avg_stage_reward(homogeneous_rewards_dict["Oracle"]) - get_avg_stage_reward(homogeneous_rewards_dict[method_name])
    for method_name in non_oracle_method_names}
incremental_heterogeneous_regret_dict = {
    method_name: get_avg_stage_reward(heterogeneous_rewards_dict["Oracle"]) - get_avg_stage_reward(heterogeneous_rewards_dict[method_name])
    for method_name in non_oracle_method_names}
incremental_nonlinear_regret_dict = {
    method_name: get_avg_stage_reward(nonlinear_rewards_dict["Oracle"]) - get_avg_stage_reward(nonlinear_rewards_dict[method_name])
    for method_name in non_oracle_method_names}

# Calculate cumulative regret
cumulative_homogeneous_regret_dict = {method_name: np.cumsum(incremental_homogeneous_regret_dict[method_name], axis=0) for method_name in non_oracle_method_names}
cumulative_heterogeneous_regret_dict = {method_name: np.cumsum(incremental_heterogeneous_regret_dict[method_name], axis=0) for method_name in non_oracle_method_names}
cumulative_nonlinear_regret_dict = {method_name: np.cumsum(incremental_nonlinear_regret_dict[method_name], axis=0) for method_name in non_oracle_method_names}

# Final regret
final_homogeneous_regret_df = pd.DataFrame({
    method_name: cumulative_homogeneous_regret_dict[method_name][-1]
    for method_name in non_oracle_method_names})
final_homogeneous_regret_df.to_csv("./checkpoints/final_homogeneous_regret-sigma.csv", index=False)

final_heterogeneous_regret_df = pd.DataFrame({
    method_name: cumulative_heterogeneous_regret_dict[method_name][-1]
    for method_name in non_oracle_method_names})
final_heterogeneous_regret_df.to_csv("./checkpoints/final_heterogeneous_regret-sigma.csv", index=False)

final_nonlinear_regret_df = pd.DataFrame({
    method_name: cumulative_nonlinear_regret_dict[method_name][-1]
    for method_name in non_oracle_method_names})
final_nonlinear_regret_df.to_csv("./checkpoints/final_nonlinear_regret-sigma.csv", index=False)

# %% [markdown]
# ## Plots

# %%
def plot_cumulative_regret(cumulative_regret_dict, setting_name, include_legend=False, loc="main", include_bands=True):
    fig, ax = plt.subplots(1, 1, figsize=(4,4))
    for i, method_name in enumerate(cumulative_regret_dict.keys()):
        color_i = f"C{i}"
        method_means = cumulative_regret_dict[method_name].mean(axis=1)
        method_range = np.arange(method_means.size)
        method_sds = cumulative_regret_dict[method_name].std(axis=1)
        method_lower = method_means - 1.96 * method_sds
        method_upper = method_means + 1.96 * method_sds
        if include_bands:
            ax.fill_between(method_range, method_lower, method_upper, color=color_i, alpha=0.1)
        ax.plot(method_range, method_means, label=method_name, color=color_i)
        
    ax.grid(which='major', color='#DDDDDD', linewidth=0.3)
    ax.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.3)
    ax.minorticks_on()
    ax.set_title(setting_name, pad=14, fontsize=16)
    ax.set_ylabel("Cumulative Regret", fontsize=14)
    ax.set_xlabel("Stage", fontsize=14)
    ax.tick_params(axis='both', labelsize=11)
    if include_legend:
        ax.legend(fontsize=11)

    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    setting_name_for_file = setting_name.replace("(", "").replace(")", "").replace(" ", "-")
    fig.savefig(f"figures/cumulative-regret-{setting_name_for_file}-{loc}-sigma.png")
    # fig.suptitle("Comparison of Cumulative Regret by Method")
    plt.show()

main_paper_methods = ["RoME", "IntelPooling", "Neural-Linear", "AC", "Standard"]

plot_cumulative_regret(
    {m:cumulative_homogeneous_regret_dict[m] for m in main_paper_methods},
    setting_name="(a) Homogeneous Users", include_legend=True)

plot_cumulative_regret(
    {m:cumulative_heterogeneous_regret_dict[m] for m in main_paper_methods},
    setting_name="(b) Heterogeneous Users", include_legend=False)

plot_cumulative_regret(
    {m:cumulative_nonlinear_regret_dict[m] for m in main_paper_methods},
    setting_name="(c) Nonlinear Setting", include_legend=False)

# %%
appendix_methods = ["RoME", "RoME-BLM", "RoME-SU", "NNR-Linear"]

plot_cumulative_regret(
    {m:cumulative_homogeneous_regret_dict[m] for m in appendix_methods},
    setting_name="(a) Homogeneous Users", include_legend=True, loc="app")

plot_cumulative_regret(
    {m:cumulative_heterogeneous_regret_dict[m] for m in appendix_methods},
    setting_name="(b) Heterogeneous Users", include_legend=False, loc="app")

plot_cumulative_regret(
    {m:cumulative_nonlinear_regret_dict[m] for m in appendix_methods},
    setting_name="(c) Nonlinear Setting", include_legend=False, loc="app")

# %% [markdown]
# ## Comparison Tables

# %% [markdown]
# ### Extra

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final_homogeneous_regret_df = pd.read_csv("./checkpoints/final_homogeneous_regret-sigma.csv")
final_heterogeneous_regret_df = pd.read_csv("./checkpoints/final_heterogeneous_regret-sigma.csv")
final_nonlinear_regret_df = pd.read_csv("./checkpoints/final_nonlinear_regret-sigma.csv")

# %%
non_oracle_method_names_sorted = [
    'RoME',
    'RoME-BLM',
    'RoME-SU',
    'NNR-Linear',
    'IntelPooling',
    'Neural-Linear',
    'Standard',
    'AC',
]

# %%
def create_comparison_df(final_regret_df):
    comparison_outer_list = []
    win_percentages = []
    for method_row in non_oracle_method_names_sorted:
        comparison_inner_list = []
        win_percentage = 0.
        for method_column in non_oracle_method_names_sorted:
            diffs = final_regret_df[method_column] - final_regret_df[method_row]
            percent_row_better = np.mean(diffs > 0)
            avg_diff = np.mean(diffs)
            p_value = ttest_1samp(diffs, popmean=0).pvalue
            if method_row == method_column:
                cell_text = "-"
            else:
                win_percentage += percent_row_better / (len(non_oracle_method_names_sorted) - 1)
                cell_text = f"{percent_row_better:.0%}{'*' if p_value < 0.05 else ''}"
            comparison_inner_list.append(cell_text)
        comparison_outer_list.append(comparison_inner_list)
        win_percentages.append(f"{win_percentage:.0%}")
    comparison_df = pd.DataFrame(
        comparison_outer_list,
        index=[f"{i+1}. {n}" for i, n in enumerate(non_oracle_method_names_sorted)],
        columns=range(1, len(non_oracle_method_names_sorted)+1))
    comparison_df["\textbf{Avg}"] = win_percentages
    latex_table = comparison_df.to_latex(escape=False).replace("%", "\%")
    print(latex_table)
    return comparison_df

# %%
homogeneous_comparison_df = create_comparison_df(final_homogeneous_regret_df)
homogeneous_comparison_df
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & 1 & 2 & 3 & 4 & 5 & 6 & 7 & 8 & 	extbf{Avg} \\
# \midrule
# 1. RoME & - & 58\% & 48\% & 52\% & 30\%* & 100\%* & 100\%* & 100\%* & 70\% \\
# 2. RoME-BLM & 42\% & - & 42\%* & 36\%* & 22\%* & 100\%* & 100\%* & 100\%* & 63\% \\
# 3. RoME-SU & 52\% & 58\%* & - & 46\% & 34\%* & 100\%* & 100\%* & 100\%* & 70\% \\
# 4. NNR-Linear & 48\% & 64\%* & 54\% & - & 32\%* & 100\%* & 100\%* & 100\%* & 71\% \\
# 5. IntelPooling & 70\%* & 78\%* & 66\%* & 68\%* & - & 100\%* & 100\%* & 100\%* & 83\% \\
# 6. Neural-Linear & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 98\%* & 100\%* & 28\% \\
# 7. Standard & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 2\%* & - & 100\%* & 15\% \\
# 8. AC & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 0\% \\
# \bottomrule
# \end{tabular}
#                       1     2     3     4     5      6      7      8  \
# 1. RoME         -   58%   48%   52%  30%*  100%*  100%*  100%*
# 2. RoME-BLM   42%     -  42%*  36%*  22%*  100%*  100%*  100%*
# 3. RoME-SU        52%  58%*     -   46%  34%*  100%*  100%*  100%*
# 4. NNR-Linear       48%  64%*   54%     -  32%*  100%*  100%*  100%*
# 5. IntelPooling    70%*  78%*  66%*  68%*     -  100%*  100%*  100%*
# 6. Neural-Linear    0%*   0%*   0%*   0%*   0%*      -   98%*  100%*
# 7. Standard         0%*   0%*   0%*   0%*   0%*    2%*      -  100%*
# 8. AC               0%*   0%*   0%*   0%*   0%*    0%*    0%*      -
#
#                   \textbf{Avg}
# 1. RoME              70%
# 2. RoME-BLM          63%
# 3. RoME-SU               70%
# 4. NNR-Linear              71%
# 5. IntelPooling            83%
# 6. Neural-Linear           28%
# 7. Standard                15%
# 8. AC                       0%

# %%
heterogeneous_comparison_df = create_comparison_df(final_heterogeneous_regret_df)
heterogeneous_comparison_df
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & 1 & 2 & 3 & 4 & 5 & 6 & 7 & 8 & 	extbf{Avg} \\
# \midrule
# 1. RoME & - & 56\% & 52\% & 24\%* & 88\%* & 100\%* & 100\%* & 100\%* & 74\% \\
# 2. RoME-BLM & 44\% & - & 50\% & 10\%* & 82\%* & 100\%* & 100\%* & 100\%* & 69\% \\
# 3. RoME-SU & 48\% & 50\% & - & 16\%* & 92\%* & 100\%* & 100\%* & 100\%* & 72\% \\
# 4. NNR-Linear & 76\%* & 90\%* & 84\%* & - & 100\%* & 100\%* & 100\%* & 100\%* & 93\% \\
# 5. IntelPooling & 12\%* & 18\%* & 8\%* & 0\%* & - & 100\%* & 100\%* & 100\%* & 48\% \\
# 6. Neural-Linear & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 96\%* & 100\%* & 28\% \\
# 7. Standard & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 4\%* & - & 100\%* & 15\% \\
# 8. AC & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 0\% \\
# \bottomrule
# \end{tabular}
#                       1     2     3     4      5      6      7      8  \
# 1. RoME         -   56%   52%  24%*   88%*  100%*  100%*  100%*
# 2. RoME-BLM   44%     -   50%  10%*   82%*  100%*  100%*  100%*
# 3. RoME-SU        48%   50%     -  16%*   92%*  100%*  100%*  100%*
# 4. NNR-Linear      76%*  90%*  84%*     -  100%*  100%*  100%*  100%*
# 5. IntelPooling    12%*  18%*   8%*   0%*      -  100%*  100%*  100%*
# 6. Neural-Linear    0%*   0%*   0%*   0%*    0%*      -   96%*  100%*
# 7. Standard         0%*   0%*   0%*   0%*    0%*    4%*      -  100%*
# 8. AC               0%*   0%*   0%*   0%*    0%*    0%*    0%*      -
#
#                   \textbf{Avg}
# 1. RoME              74%
# 2. RoME-BLM          69%
# 3. RoME-SU               72%
# 4. NNR-Linear              93%
# 5. IntelPooling            48%
# 6. Neural-Linear           28%
# 7. Standard                15%
# 8. AC                       0%

# %% [markdown]
# ### Nonlinear Setting

# %%
nonlinear_comparison_df = create_comparison_df(final_nonlinear_regret_df)
nonlinear_comparison_df
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & 1 & 2 & 3 & 4 & 5 & 6 & 7 & 8 & 	extbf{Avg} \\
# \midrule
# 1. RoME & - & 54\% & 100\%* & 86\%* & 96\%* & 100\%* & 100\%* & 100\%* & 91\% \\
# 2. RoME-BLM & 46\% & - & 98\%* & 94\%* & 98\%* & 100\%* & 100\%* & 100\%* & 91\% \\
# 3. RoME-SU & 0\%* & 2\%* & - & 16\%* & 52\% & 96\%* & 100\%* & 100\%* & 52\% \\
# 4. NNR-Linear & 14\%* & 6\%* & 84\%* & - & 82\%* & 100\%* & 100\%* & 100\%* & 69\% \\
# 5. IntelPooling & 4\%* & 2\%* & 48\% & 18\%* & - & 98\%* & 100\%* & 100\%* & 53\% \\
# 6. Neural-Linear & 0\%* & 0\%* & 4\%* & 0\%* & 2\%* & - & 98\%* & 100\%* & 29\% \\
# 7. Standard & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 2\%* & - & 100\%* & 15\% \\
# 8. AC & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & 0\%* & - & 0\% \\
# \bottomrule
# \end{tabular}
#                       1    2      3     4     5      6      7      8  \
# 1. RoME         -  54%  100%*  86%*  96%*  100%*  100%*  100%*
# 2. RoME-BLM   46%    -   98%*  94%*  98%*  100%*  100%*  100%*
# 3. RoME-SU        0%*  2%*      -  16%*   52%   96%*  100%*  100%*
# 4. NNR-Linear      14%*  6%*   84%*     -  82%*  100%*  100%*  100%*
# 5. IntelPooling     4%*  2%*    48%  18%*     -   98%*  100%*  100%*
# 6. Neural-Linear    0%*  0%*    4%*   0%*   2%*      -   98%*  100%*
# 7. Standard         0%*  0%*    0%*   0%*   0%*    2%*      -  100%*
# 8. AC               0%*  0%*    0%*   0%*   0%*    0%*    0%*      -
#
#                   \textbf{Avg}
# 1. RoME              91%
# 2. RoME-BLM          91%
# 3. RoME-SU               52%
# 4. NNR-Linear              69%
# 5. IntelPooling            53%
# 6. Neural-Linear           29%
# 7. Standard                15%
# 8. AC                       0%

# %%
final_nonlinear_regret_df
# Out:
#     IntelPooling  RoME-BLM  RoME  RoME-SU          AC  \
# 0      55.576990       37.829677   33.130566  53.202328  138.513413
# 1      48.923903       32.267948   29.770551  55.600852  140.556270
# 2      56.722796       40.432146   36.693159  58.855300  141.801915
# 3      46.745882       33.728666   46.295480  56.408517  149.383349
# 4      50.538686       38.229288   44.318325  49.536519  142.731606
# 5      61.729105       35.002568   42.885725  54.001176  145.028294
# 6      50.860804       40.719988   49.264208  52.119532  139.644067
# 7      50.807392       49.199958   47.329474  50.678277  139.019617
# 8      56.341955       38.397708   44.475579  47.388263  136.521394
# 9      61.939008       47.429518   30.446546  57.235536  140.829186
# 10     61.517221       41.978697   45.575535  56.416867  142.380755
# 11     58.277170       34.509856   48.278055  56.890587  142.995263
# 12     51.282720       38.281481   43.868641  51.762595  146.052129
# 13     51.874542       34.114047   35.090951  58.192975  133.504922
# 14     51.032911       38.967046   42.560159  46.268916  142.598500
# 15     61.522746       45.000327   44.984138  64.243429  145.384761
# 16     53.562890       42.498712   37.191701  56.151540  143.123987
# 17     56.871841       49.442500   38.604144  55.632250  145.037578
# 18     52.296569       39.897342   33.805184  41.522939  140.533977
# 19     64.004699       41.073412   40.280620  67.959301  137.244472
# 20     54.982109       37.749023   48.223367  62.216166  143.498067
# 21     68.398265       42.862512   41.123360  60.925092  145.742553
# 22     50.323960       36.230477   39.082591  47.722789  141.232783
# 23     43.940783       43.961639   53.580607  61.809245  146.715340
# 24     58.870689       50.361499   59.772515  60.498429  140.404113
# 25     54.475015       37.792267   33.311663  48.586933  140.181856
# 26     54.649352       48.399076   42.206850  55.407957  144.477938
# 27     72.301914       37.918277   44.113089  65.625306  148.005048
# 28     56.119876       39.973763   32.822407  59.042244  144.076621
# 29     61.640178       35.280421   35.081815  58.599061  143.336099
# 30     64.175446       41.829901   40.808778  54.354467  146.901972
# 31     63.534166       39.204574   43.604100  62.182321  139.109338
# 32     58.022521       43.005015   35.473348  65.830315  148.116072
# 33     55.950615       45.878167   39.455948  59.249434  149.548246
# 34     63.710228       37.891720   43.823356  63.326561  146.300877
# 35     56.772253       45.977297   41.886797  59.477106  145.692681
# 36     59.408928       45.571462   38.582911  56.824229  145.695721
# 37     62.954547       41.653283   42.682394  60.063456  145.997464
# 38     58.384693       48.237231   39.081076  66.850400  151.704396
# 39     49.429000       40.273760   41.412004  54.189610  144.337853
# 40     54.535851       36.786027   43.068178  57.175905  137.508303
# 41     61.385240       51.566797   42.606206  61.367703  139.287204
# 42     63.927388       51.074612   39.939196  52.654077  143.116442
# 43     55.551588       36.689565   38.510318  63.879722  141.050021
# 44     56.236183       40.565694   35.709740  55.020205  148.950528
# 45     58.268356       53.784727   31.182015  51.545926  141.507458
# 46     50.215999       48.110822   40.735727  57.235206  137.488988
# 47     50.396227       44.107014   49.289295  66.002976  148.212770
# 48     69.193393       37.013210   48.000760  55.054355  140.082458
# 49     55.409855       38.942825   37.905936  57.993054  138.596693
#
#      Standard  Neural-Linear  NNR-Linear
# 0   84.164855      69.756559   50.465717
# 1   69.450685      76.171734   50.160768
# 2   75.972919      65.328150   46.095840
# 3   86.952215      69.521731   42.921491
# 4   79.730129      65.213344   46.876672
# 5   83.884281      73.542914   46.822268
# 6   86.083170      75.418716   54.588442
# 7   81.792206      68.540619   41.255705
# 8   86.701797      63.225922   42.156404
# 9   87.312895      70.982424   54.800396
# 10  84.220612      70.686401   52.689352
# 11  82.371890      69.462676   49.020456
# 12  82.789863      72.890206   50.190615
# 13  81.067391      65.365809   61.140790
# 14  76.726821      71.396466   51.061568
# 15  87.710628      79.517424   46.610600
# 16  83.375378      70.007682   46.920337
# 17  88.887055      62.440189   51.425418
# 18  84.515192      66.294732   42.668139
# 19  86.005826      68.275623   42.927398
# 20  89.722356      72.267847   50.974878
# 21  82.573444      69.846805   51.470368
# 22  77.674118      69.854600   44.131694
# 23  85.222269      73.220176   51.536431
# 24  85.461643      70.437156   54.589326
# 25  82.879117      66.444264   54.025119
# 26  90.305259      72.986256   67.235460
# 27  90.612130      76.395427   53.645541
# 28  78.366289      69.799961   48.505292
# 29  90.771503      62.710990   57.561877
# 30  83.177053      74.832629   48.201284
# 31  82.671295      68.333060   51.105448
# 32  81.092797      69.772555   57.953888
# 33  83.677102      72.416521   48.101625
# 34  75.479292      65.222551   53.312106
# 35  85.955299      69.677189   52.252077
# 36  93.675292      75.319088   55.833799
# 37  81.300781      73.498496   56.699888
# 38  90.846935      78.525534   65.401487
# 39  83.419900      73.768043   62.423733
# 40  85.100476      71.384686   50.384238
# 41  89.096055      71.331670   54.315942
# 42  85.619451      79.731350   50.626475
# 43  86.003789      61.119684   50.077558
# 44  90.722266      70.630792   54.030784
# 45  86.962342      72.835820   53.568393
# 46  87.841111      80.372248   52.802834
# 47  80.782026      63.962595   49.126246
# 48  81.352122      67.457130   46.754308
# 49  81.064673      69.702205   48.544099

# %%
sns.kdeplot(data=final_homogeneous_regret_df)
plt.show()

sns.kdeplot(data=final_heterogeneous_regret_df)
plt.show()

sns.kdeplot(data=final_nonlinear_regret_df)
plt.show()
